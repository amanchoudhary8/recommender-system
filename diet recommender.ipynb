# %%
import pandas as pd
import pandas.io.sql as sql
from pandas import *
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
import numpy as np
from scipy.cluster.vq import kmeans,vq
from scipy.spatial.distance import cdist
import matplotlib.pyplot as plt
import pandas as pd
import sklearn.metrics as sm
from matplotlib import pyplot
from sklearn.cluster import KMeans
from scipy import cluster
import MySQLdb
import sys
import mysql.connector

# %%
#Input age, gender,bloodgroup, blood sugar level, food and amount of food to be consumed by the user
age=int(input("Enter your age:"))
upper=age + 5
lower=age - 5
gender= input("Enter your gender(F/M):")
bloodgroup= input("Enter your blood group(A,B,AB,O):")
sugarlevel= float(input("Enter your blood sugar level:"))
food=input("Enter your food:")
serving=float(input("Enter amount of food(gms):"))
# Out:
# Enter your age:50
# Enter your gender(F/M):M
# Enter your blood group(A,B,AB,O):A
# Enter your blood sugar level:400
# Enter your food:Bread roll, from white flour, fast food style
# Enter amount of food(gms):500

# %%
# load the dataset into pandas dataframe
dataNutrition = pd.read_csv('Nutrition Dataset filled.csv',usecols=["FoodName","GyclemicIndex","Energywithdietaryfibre(kJ)",
                                                             "Energywithoutdietaryfibre(kJ)","Totalfat(g)",
                                                             "Availablecarbohydrateswithsugaralcohols(g)",
                                                             "Availablecarbohydrateswithoutsugaralcohol(g)",
                                                             "Starch(g)",
                                                             "Alcohol(g)","Totalsaturatedfat(g)",
                                                             "Totalmonounsaturatedfat(g)",
                                                             "Totalpolyunsaturatedfat(g)","Totaltransfattyacids(mg)"])

# %%
dataNutrition.head()
# Out:
#                         FoodName  GyclemicIndex  Energywithdietaryfibre(kJ)  \
# 0           Beef, extract, bonox              0                         401
# 1                   Basil, dried              0                        1079
# 2        Cardamom, seeds, ground              0                        1333
# 3          Chilli (chili) powder              0                        1441
# 4  Chilli (chili), dried, ground              0                        1573
#
#    Energywithoutdietaryfibre(kJ)  Totalfat(g)  \
# 0                            401          0.2
# 1                            774          5.5
# 2                           1109          6.7
# 3                           1167         16.8
# 4                           1355         16.8
#
#    Availablecarbohydrateswithsugaralcohols(g)  \
# 0                                         6.5
# 1                                        15.5
# 2                                        40.5
# 3                                        20.5
# 4                                        29.6
#
#    Availablecarbohydrateswithoutsugaralcohol(g)  Starch(g)  Alcohol(g)  \
# 0                                           6.5        6.5         0.0
# 1                                          15.5       15.5         0.0
# 2                                          40.5       31.0         0.0
# 3                                          20.5       10.4         0.0
# 4                                          29.6       19.2         0.0
#
#    Totalsaturatedfat(g)  Totalmonounsaturatedfat(g)  \
# 0                  0.00                        0.00
# 1                  2.36                        1.40
# 2                  2.20                        2.81
# 3                  2.41                        3.15
# 4                  2.42                        3.16
#
#    Totalpolyunsaturatedfat(g)  Totaltransfattyacids(mg)
# 0                        0.00                       0.0
# 1                        0.61                       0.0
# 2                        1.39                       0.0
# 3                        7.85                       0.0
# 4                        7.89                       0.0

# %%
dataNutrition.columns
# Out:
# Index(['FoodName', 'GyclemicIndex', 'Energywithdietaryfibre(kJ)',
#        'Energywithoutdietaryfibre(kJ)', 'Totalfat(g)',
#        'Availablecarbohydrateswithsugaralcohols(g)',
#        'Availablecarbohydrateswithoutsugaralcohol(g)', 'Starch(g)',
#        'Alcohol(g)', 'Totalsaturatedfat(g)', 'Totalmonounsaturatedfat(g)',
#        'Totalpolyunsaturatedfat(g)', 'Totaltransfattyacids(mg)'],
#       dtype='object')

# %%
dataNutrition.shape
# Out:
# (5740, 13)

# %%
dataNutrition.describe()
# Out:
#        GyclemicIndex  Energywithdietaryfibre(kJ)  \
# count    5740.000000                 5740.000000
# mean       37.061847                  880.160801
# std        25.136751                  645.450232
# min         0.000000                    0.000000
# 25%        10.000000                  386.000000
# 50%        30.000000                  742.000000
# 75%        60.000000                 1229.000000
# max       100.000000                 3703.000000
#
#        Energywithoutdietaryfibre(kJ)  Totalfat(g)  \
# count                    5740.000000  5740.000000
# mean                      862.882056    10.109983
# std                       640.789714    14.657683
# min                         0.000000     0.000000
# 25%                       371.000000     1.400000
# 50%                       734.000000     5.600000
# 75%                      1196.250000    12.500000
# max                      3703.000000   100.000000
#
#        Availablecarbohydrateswithsugaralcohols(g)  \
# count                                 5740.000000
# mean                                    18.395662
# std                                     22.194143
# min                                      0.000000
# 25%                                      1.000000
# 50%                                      9.550000
# 75%                                     26.825000
# max                                    100.000000
#
#        Availablecarbohydrateswithoutsugaralcohol(g)    Starch(g)   Alcohol(g)  \
# count                                   5740.000000  5740.000000  5740.000000
# mean                                      18.290819    10.289477     0.148014
# std                                       22.128313    15.988358     2.062310
# min                                        0.000000     0.000000     0.000000
# 25%                                        0.900000     0.000000     0.000000
# 50%                                        9.400000     1.300000     0.000000
# 75%                                       26.800000    15.125000     0.000000
# max                                      100.000000    88.400000   100.000000
#
#        Totalsaturatedfat(g)  Totalmonounsaturatedfat(g)  \
# count           5740.000000                 5740.000000
# mean               3.653233                    3.911237
# std                6.068300                    6.471672
# min                0.000000                    0.000000
# 25%                0.290000                    0.310000
# 50%                1.500000                    2.085000
# 75%                4.362500                    4.670000
# max               92.410000                   80.590000
#
#        Totalpolyunsaturatedfat(g)  Totaltransfattyacids(mg)
# count                 5740.000000               5740.000000
# mean                     1.711493                211.312470
# std                      4.256266                503.503916
# min                      0.000000                  0.000000
# 25%                      0.150000                  1.890000
# 50%                      0.770000                 54.365000
# 75%                      1.540000                202.722500
# max                     72.560000               9712.960000

# %%
#Check whether food entered by user is present in the dataset
list={food}
f=dataNutrition[dataNutrition['FoodName'].isin(list)] 
descision="not decided"
data=[{}]  
dataf1=[] 
j=0
flag=11 

#if food is present in the dataset, calculations for glycemic index are done directly
if(f.size>0):
    flag=1
    netcarbs=float(f["Totalfat(g)"]+f["Availablecarbohydrateswithsugaralcohols(g)"]+f["Availablecarbohydrateswithoutsugaralcohol(g)"]
                   -f["Alcohol(g)"]-f["Starch(g)"]+f["Totalsaturatedfat(g)"]+f["Totalmonounsaturatedfat(g)"]+f["Totalpolyunsaturatedfat(g)"]
                   +f["Totaltransfattyacids(mg)"])
    GI=f["GyclemicIndex"].values
    GlycemicLoad=(float)(netcarbs*GI*serving)/10000.0 # serving variable is being used here
    print ("Glycemic Load: ",GlycemicLoad)
    if(GlycemicLoad<=10.0):
        print("Food is appropriate for consumption")
    elif(GlycemicLoad<=19.0 and sugarlevel<=110.0):
        print("Food is appropriate for consumption")
    elif(GlycemicLoad>=20.0 and GI<=55.0):
        print("If food is consumed in lesser quatity, it would be fit for consumption")
        descision = input("Do you want a healthier food substitute(Y/N):")
    else:
        print("Food is inappropriate for consumption")
        descision=input("Do you want a healthier food substitute(Y/N):")
        
#if food is not present in the dataset, user is asked to enter the nutrient values for calculation of glycemic index
else:
    flag=0
    data=[{"FoodName":food,"Energywithdietaryfibre(kJ)":float(input("Enter Energywithdietaryfibre(kJ):")),
    "Energywithoutdietaryfibre(kJ)":float(input("Enter Energywithoutdietaryfibre(kJ):")),
    "Moisture(g)":float(input("Enter Moisture(g):")),
    "Protein(g)":float(input("Enter Protein(g):")),
    "Totalfat(g)":float(input("Enter Totalfat(g):")),
    "Availablecarbohydrateswithsugaralcohols(g)":float(input("Enter Available carbohydrates with sugar alcohols(g):")),
    "Availablecarbohydrateswithoutsugaralcohol(g)":float(input("Enter Availablecarbohydrateswithoutsugaralcohol(g):")),
    "Starch(g)":float(input("Enter Starch(g):")),
    "Totalsugars(g)":float(input("Enter Totalsugars(g):")),
    "Addedsugars(g)":float(input("Enter Addedsugars(g):")),
    "Freesugars(g)":float(input("Enter Freesugars(g):")),
    "Dietaryfibre(g)":float(input("Enter Dietaryfibre(g):")),
    "Alcohol(g)":float(input("Enter Alcohol(g):")),
    "Ash(g)":float(input("Enter Ash(g):")),
    "PreformedvitaminA(retinol)(g):":float(input("Enter Preformed vitamin A(retinol)(g):")),
    "Beta - carotene(g)":float(input("Enter Beta - carotene(g):")),
    "ProvitaminA(b - carotene equivalents)(g)":float(input("Enter Provitamin A(b - carotene equivalents) (g):")),
    "VitaminAretinolequivalents(g)":float(input("Enter Vitamin A retinol equivalents(g):")),
    "Thiamin(B1)(mg)":float(input("Enter Thiamin(B1)(mg):")),
    "Riboflavin(B2)(mg)":float(input("Enter Riboflavin(B2)(mg):")),
    "Niacin(B3)(mg)":float(input("Enter Niacin(B3)(mg):")),
    "Niacinderivedequivalents(mg)":float(input("Enter Niacin derived equivalents(mg):")),
    "Folate, natural(g)":float(input("Enter Folate, natural(g):")),
    "Folic acid(g):":float(input("Enter Folic acid(g):")),
    "Total Folates(g)":float(input("Enter Total Folates(g):")),
    "Dietaryfolateequivalents(g)":float(input("Enter Dietary folate equivalents(g):")),
    "VitaminB6(mg)":float(input("Enter Vitamin B6(mg):")),
    "VitaminB12(g)":float(input("Enter Vitamin B12(g):")),
    "VitaminC(mg)":float(input("Enter Vitamin C(mg):")),
    "Alpha-tocopherol(mg)":float(input("Enter Alpha - tocopherol(mg):")),
    "VitaminE(mg)":float(input("Enter Vitamin E(mg):")),
    "Calcium(Ca)(mg)":float(input("Enter Calcium(Ca)(mg):")),
    "Iodine(I)(g)":float(input("Enter Iodine(I)(g):")),
    "Iron(Fe)(mg)":float(input("Enter Iron(Fe)(mg):")),
    "Magnesium(Mg)(mg)":float(input("Enter Magnesium(Mg)(mg):")),
    "Phosphorus(P)(mg)":float(input("Enter Phosphorus(P)(mg):")),
    "Potassium(K)(mg)":float(input("Enter Potassium(K)(mg):")),
    "Selenium(Se)(g)":float(input("Enter Selenium(Se)(g):")),
    "Sodium(Na)(mg)":float(input("Enter Sodium(Na)(mg):")),
    "Zinc(Zn)(mg)":float(input("Enter Zinc(Zn)(mg):")),
    "Caffeine(mg)":float(input("Enter Caffeine(mg):")),
    "Cholesterol(mg)":float(input("Enter Cholesterol(mg):")),
    "Tryptophan(mg)":float(input("Enter Tryptophan(mg):")),
    "Totalsaturatedfat(g)":float(input("Enter Totalsaturatedfat(g):")),
    "Totalmonounsaturatedfat(g)":float(input("Enter Totalmonounsaturatedfat(g):")),
    "Totalpolyunsaturatedfat(g)":float(input("Enter Totalpolyunsaturatedfat(g):")),
    "Linoleic acid(g)":float(input("Enter Linoleic acid(g):")),
    "Alpha - linolenic acid(g)":float(input("Enter Alpha - linolenic acid(g):")),
    "C20:5 w3 Eicosapentaenoic(mg)":float(input("Enter C20:5 w3 Eicosapentaenoic(mg):")),
    "C22:5 w3 Docosapentaenoic(mg)":float(input("Enter C22:5 w3 Docosapentaenoic(mg):")),
    "C22:6 w3 Docosahexaenoic(mg)":float(input("Enter C22:6 w3 Docosahexaenoic(mg):")),
    "Total long chain omega3 fatty acids(mg)":float(input("Enter Total long chain omega3 fatty acids(mg):")),
    "Totaltransfattyacids(mg)":float(input("Enter Totaltransfattyacids(mg):"))}]
    dataf = pd.DataFrame(data)
    dataf1= dataf
    
    
    #Partioning features and label
    dataNutrition = dataNutrition[dataNutrition["GyclemicIndex"].notnull()]
    diabetes_X = dataNutrition.drop('GyclemicIndex', 1)
    diabetes_X=diabetes_X.drop('FoodName', 1)
    diabetes_Y = dataNutrition["GyclemicIndex"]

    #Preprocessing: Features are normalised
    robust_scaler = RobustScaler()
    diabetes_X=robust_scaler.fit_transform(diabetes_X)
    diabetes_X_train = diabetes_X

    # Build a forest and compute the feature importances (done once for feature selection)
    forest = ExtraTreesClassifier(n_estimators=250,random_state=0)
    forest.fit(diabetes_X, diabetes_Y)
    importances = forest.feature_importances_
    std = np.std([tree.feature_importances_ for tree in forest.estimators_],
                 axis=0)
    indices = np.argsort(importances)[::-1]

    # Print the feature ranking
    #print("Feature ranking:")
    #for f in range(diabetes_X.shape[1]):
        #print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

    #Predicting GLycemic Index using Linear Regression
    diabetes_y_train = diabetes_Y
    regr = linear_model.LinearRegression()

    # Train the model using the training sets
    regr.fit(diabetes_X_train, diabetes_y_train)
    diabetes_X_test=dataf[["Energywithdietaryfibre(kJ)","Energywithoutdietaryfibre(kJ)","Totalfat(g)",
                         "Availablecarbohydrateswithsugaralcohols(g)","Availablecarbohydrateswithoutsugaralcohol(g)","Starch(g)",
                         "Alcohol(g)","Totalsaturatedfat(g)","Totalmonounsaturatedfat(g)","Totalpolyunsaturatedfat(g)",
                         "Totaltransfattyacids(mg)"]].values
    print (diabetes_X_test)
    GI=int(regr.predict(diabetes_X_test))
    print("Glycemic Index: ",GI)
    netcarbs = float(dataf["Totalfat(g)"] + dataf["Availablecarbohydrateswithsugaralcohols(g)"] + dataf[
            "Availablecarbohydrateswithoutsugaralcohol(g)"]
                         - dataf["Alcohol(g)"] - dataf["Starch(g)"] + dataf["Totalsaturatedfat(g)"] + dataf[
                             "Totalmonounsaturatedfat(g)"] + dataf["Totalpolyunsaturatedfat(g)"]
                         + dataf["Totaltransfattyacids(mg)"])
    GlycemicLoad = (float)(netcarbs * GI * serving) / 10000.0
    print("Glycemic Load: ",GlycemicLoad)

    if (GlycemicLoad <= 10.0): #condition for low GL
        print("Food is appropriate for consumption")
    elif (GlycemicLoad <= 19.0 and sugarlevel <= 110.0): #condition for medium GL and normal blood sugar level
        print("Food is appropriate for consumption")
    elif (GlycemicLoad >= 20.0 and GI <= 55.0): #condition for high GL but low GI
        print("If food is consumed in lesser quatity, it would be fit for consumption")
        descision = input("Do you still want a healthier food substitute(Y/N):")
    else: #Condition for high GI and GL
        print("Food is inappropriate for consumption")
        descision = input("Do you want a healthier food substitute(Y/N):")


        # The mean squared error
    #print("Mean squared error: %.2f"
          #% np.mean((regr.predict(diabetes_X_test) - diabetes_y_test) ** 2))
    # variance score
    #print('Variance score: %.2f' % regr.score(diabetes_X_test, diabetes_y_test))
# Out:
# Glycemic Load:  407.43
# Food is inappropriate for consumption
# Do you want a healthier food substitute(Y/N):Y

# %%
answer="n"
if(descision=="Y" or descision=="y"):#when the user wants a healthier substitute
    print("Finding suitable substitute...")
    print()
    cnx=""
    try:
        cnx = mysql.connector.connect(user="root", passwd="Amankumarjha@1234", host="localhost", port=3306)
        print("Status: Connection established to the database")
    except:
        print("Status: not connected")

    print()
    # If the user entered food already has a case saved with better substitute
    sqlstring = 'select * from diabeticnutritionist.nutrition where food="%s"' % food
    df = pd.read_sql(sqlstring, cnx)
    if (df.size > 0):
        df1 = pd.read_sql_query(
            'select * from diabeticnutritionist.nutrition where bloodgroup=%(bloodgroup)s and food=%(food)s and gender=%(gender)s and age BETWEEN %(lower)s AND %(upper)s',
            cnx, params={"food": food, "gender": gender, "lower": lower, "upper": upper, "bloodgroup": bloodgroup})
        if(df1.size>0):
            substitute=df1["sub"].values
            print ("Healthier substitute will be: "+substitute)
            answer = input("Is this a good substitute for you(Y/N):")
    
    
    
    
    #when the user is unsatisfied with substitute or no substitute exists in our knowledge base for user entered food
    if(answer=="n" or answer=="N" or df.size<=0):
        dataNutrition1 = pd.read_csv('Nutrition Dataset.csv',usecols=["FoodName", "GyclemicIndex", "Energywithdietaryfibre(kJ)","Energywithoutdietaryfibre(kJ)", "Protein(g)",
                                                                      "Availablecarbohydrateswithsugaralcohols(g)","Availablecarbohydrateswithoutsugaralcohol(g)",
                                                                       "Dietaryfibre(g)", "VitaminAretinolequivalents(g)", "Thiamin(B1)(mg)",
                                                                       "Riboflavin(B2)(mg)", "Niacin(B3)(mg)", "Dietaryfolateequivalents(g)",
                                                                       "VitaminB6(mg)", "VitaminB12(g)", "VitaminC(mg)",
                                                                       "Alpha-tocopherol(mg)", "VitaminE(mg)", "Calcium(Ca)(mg)",
                                                                       "Iodine(I)(g)", "Iron(Fe)(mg)", "Magnesium(Mg)(mg)","Phosphorus(P)(mg)",
                                                                       "Potassium(K)(mg)", "Selenium(Se)(g)", "Sodium(Na)(mg)",
                                                                       "Zinc(Zn)(mg)"])



        value=[]
        if(flag==1):#when user entered food exists in dataset
            value=dataNutrition1[dataNutrition1["FoodName"]==food]
            value=value.drop('GyclemicIndex', 1)
        if(flag==0):#when user entered food does not exists in dataset
            value= dataf1[["FoodName", "Energywithdietaryfibre(kJ)","Energywithoutdietaryfibre(kJ)", "Protein(g)",
                                                                      "Availablecarbohydrateswithsugaralcohols(g)","Availablecarbohydrateswithoutsugaralcohol(g)",
                                                                       "Dietaryfibre(g)", "VitaminAretinolequivalents(g)", "Thiamin(B1)(mg)",
                                                                       "Riboflavin(B2)(mg)", "Niacin(B3)(mg)", "Dietaryfolateequivalents(g)",
                                                                       "VitaminB6(mg)", "VitaminB12(g)", "VitaminC(mg)",
                                                                       "Alpha-tocopherol(mg)", "VitaminE(mg)", "Calcium(Ca)(mg)",
                                                                       "Iodine(I)(g)", "Iron(Fe)(mg)", "Magnesium(Mg)(mg)","Phosphorus(P)(mg)",
                                                                       "Potassium(K)(mg)", "Selenium(Se)(g)", "Sodium(Na)(mg)",
                                                                       "Zinc(Zn)(mg)"]]




        #Running Kmeans to find a healthier substitute
        dataNutritioncopy=dataNutrition1.copy(deep=True);
        dataNutrition1 = dataNutrition1[dataNutrition1["GyclemicIndex"].notnull()]
        dataNutrition1 =dataNutrition1[dataNutrition1["GyclemicIndex"]<55]

 
    ############################################################################################################


        diabetes_X = dataNutrition1.drop('GyclemicIndex', 1)
        diabetes_X = diabetes_X.append(value)
        diabetes_X = diabetes_X.drop('FoodName', 1)
        X = np.array(diabetes_X)





    #####################################################################################################################

        cluster_array = [cluster.vq.kmeans(diabetes_X, i) for i in range(1, 10)]

    #     plt.plot([var for (cent, var) in cluster_array])
    #     plt.show()

        kmeans = KMeans(n_clusters=8)
        kmeans.fit(X)
        centroid = kmeans.cluster_centers_
        labels = kmeans.labels_

    #     print (centroid)
    #     print(type(labels))
        unique, counts = np.unique(labels, return_counts=True)

    #     print(np.asarray((unique, counts)).T)

        for i in range(3):
            ds = X[np.where(labels == i)]
            # pyplot.plot(ds[:, 0], ds[:, 1], 'o')
            # lines = pyplot.plot(centroid[i, 0], centroid[i, 1], 'kx')
            # plt.setp(lines, ms=20.0)
            # plt.setp(lines, mew=5.0)
            # plt.show()
        diabetes_X["labels"]=labels
        listsub= diabetes_X[diabetes_X['labels'] == labels[labels.size-1]].index.values
        min=100
        l=listsub[1]

        np.set_printoptions(threshold=sys.maxsize)
    #     print(listsub)
        np.set_printoptions(threshold = False)


    #########################################################################################################################


    #     print(listsub[2633])

    #     print(dataNutritioncopy.shape)
    #     print(dataNutritioncopy.iloc[listsub[2633]])

        #finding the best substitute from the ones suggested by kmeans algorithm
        for i in range(0,listsub.size-1):
    #         print (i, end =" ")
            if(dataNutritioncopy.iloc[listsub[i],1]<min and dataNutritioncopy.iloc[listsub[i],0]!=food):
                min=dataNutritioncopy.iloc[listsub[i],1]
                j=i
                l=listsub[i]
        listsub = np.array(listsub)
        listsub = np.delete(listsub, j)
        substitute= dataNutritioncopy.iloc[l,0]
        print ("Healthier substitute will be: "+substitute)
        answer = input("Is this a good substitute for you(Y/N):")

        
 #########################################################################################################################       
        
        
        
        
        #till the user finds an appropriate substitute the search goes on and once the user finds the substitute it is saved in knowledge base for knowledge
        if(answer=="y" or answer=="Y"):
            cur = cnx.cursor()
            values=(age,gender,bloodgroup,str(sugarlevel),food,substitute)
            cur.execute('insert into diabeticnutritionist.nutrition (age,gender,bloodgroup,sugarlevel,food,sub) values (%s,%s,%s,%s,%s,%s)',values)
            cnx.commit()
        else:
            k=1
            a=0
            while(answer!="Y" and answer!="y"):
                l=listsub[k]
                substitute = dataNutrition1.iloc[l,0]
                print ("Healthier substitute will be: " + substitute)
                answer = input("Is this a good substitute for you(Y/N):")
                if(k<listsub.size-2):
                    k=k+1
                else:
                    a=1
                    print("no more substitutes available")
                    answer="y"
            if a==0:
                cur = cnx.cursor()
                values = (age, gender, bloodgroup, str(sugarlevel), food, substitute)
                cur.execute(
                    'insert into diabeticnutritionist.nutrition (age,gender,bloodgroup,sugarlevel,food,sub) values (%s,%s,%s,%s,%s,%s)',
                    values)
                cnx.commit()


#########################################################################################################################       

    print()
    print("Thank You!!")
# Out:
# Finding suitable substitute...
#
# Status: Connection established to the database
# C:\Anaconda\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Healthier substitute will be: Bread, soy & linseed, commercial
# Is this a good substitute for you(Y/N):Y
#
# Thank You!!
